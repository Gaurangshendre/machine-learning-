# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('covid_toy.csv')

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
#handling msiing values for fever , one hot encoding for gender anfd city and ordinal encoding for cough
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['has_covid']),df['has_covid'],
                                                test_size=0.2)

# %%
##AAm jindagi
si=SimpleImputer()
# adding simple imputer to fever col
si = SimpleImputer()
X_train_fever = si.fit_transform(X_train[['fever']])

# also the test data
X_test_fever = si.fit_transform(X_test[['fever']])

# %%
# Ordinalencoding -> cough
oe=OrdinalEncoder(categories=[['Mild','Strong']])
X_train_cough=oe.fit_transform(X_train[['cough']])
X_test_cough=oe.fit_transform(X_test[['cough']])
X_test_cough.shape
# Out:
# (20, 1)

# %%
# OneHotEncoding -> gender,city
ohe = OneHotEncoder(drop='first')
X_train_gender_city = ohe.fit_transform(X_train[['gender','city']])

# also the test data
X_test_gender_city = ohe.fit_transform(X_test[['gender','city']])

X_train_gender_city.shape
# Out:
# (80, 4)

# %%
# Extracting Age
X_train_age = X_train.drop(columns=['gender','fever','cough','city']).values

# also the test data
X_test_age = X_test.drop(columns=['gender','fever','cough','city']).values

X_train_age.shape
# Out:
# (80, 1)

# %%
X_train_transformed = np.concatenate(
    (X_train_age, X_train_fever, X_train_gender_city.toarray(), X_train_cough),
    axis=1
)

X_test_transformed = np.concatenate(
    (X_test_age, X_test_fever, X_test_gender_city.toarray(), X_test_cough),
    axis=1
)

X_train_transformed.shape
# Out:
# (80, 7)

# %% [markdown]
# # mentos jindagi(using columntransformer)

# %%
from sklearn.compose import ColumnTransformer

# %%
trans=ColumnTransformer(transformers=[
    ('tnf1',SimpleImputer(),['fever']),
    ('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
    ('tnf3',OneHotEncoder(drop='first'),['gender','city'])
],remainder='passthrough')

# %%
trans.fit_transform(X_train)
# Out:
# array([[100.       ,   0.       ,   1.       ,   0.       ,   0.       ,
#           0.       ,  10.       ],
#        [ 99.       ,   0.       ,   0.       ,   0.       ,   0.       ,
#           1.       ,  14.       ],
#        [103.       ,   0.       ,   0.       ,   0.       ,   1.       ,
#           0.       ,  48.       ],
#        [ 98.       ,   1.       ,   0.       ,   1.       ,   0.       ,
#           0.       ,  40.       ],
#        [102.       ,   0.       ,   1.       ,   0.       ,   0.       ,
#           0.       ,  64.       ],
#        [ 98.       ,   0.       ,   0.       ,   0.       ,   0.       ,
#           1.       ,  65.       ],
#        [104.       ,   0.       ,   0.       ,   0.       ,   1.       ,
#           0.       ,  17.       ],
#        [100.5890411,   1.       ,   0.       ,   0.       ,   0.       ,
#           1.       ,  34.       ],
#        [104.       ,   1.       ,   0.       ,   0.       ,   0.       ,
# ...

# %%
trans.fit_transform(X_test)
# Out:
# array([[ 99.        ,   1.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,  66.        ],
#        [102.        ,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,  69.        ],
#        [104.        ,   0.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,  51.        ],
#        [102.        ,   1.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,  24.        ],
#        [104.        ,   0.        ,   0.        ,   0.        ,
#           1.        ,   0.        ,   6.        ],
#        [101.94117647,   1.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,  71.        ],
#        [103.        ,   1.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,  46.        ],
#        [101.94117647,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,  84.        ],
# ...
